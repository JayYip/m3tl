# %% [markdown]
# ## Define new problem type and data reading function
#
# We'll use IMDB dataset as example

# %%
import tensorflow as tf
from tensorflow import keras

# %%
cd ../
# Out:
# /data3/yjp/bert-multitask-learning

# %%
from bert_multitask_learning import (get_or_make_label_encoder, FullTokenizer, 
                                     create_single_problem_generator, train_bert_multitask, 
                                     eval_bert_multitask, DynamicBatchSizeParams, TRAIN, EVAL, PREDICT)
import pickle

# %%
new_problem_type = {'imdb_cls': 'cls'}

def imdb_cls(params, mode):
    tokenizer = FullTokenizer(vocab_file=params.vocab_file)
    
    # get data
    (train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=10000)
    label_encoder = get_or_make_label_encoder(params, 'imdb_cls', mode, train_labels+test_labels)
    word_to_id = keras.datasets.imdb.get_word_index()
    index_from=3
    word_to_id = {k:(v+index_from) for k,v in word_to_id.items()}
    word_to_id["<PAD>"] = 0
    word_to_id["<START>"] = 1
    word_to_id["<UNK>"] = 2
    id_to_word = {value:key for key,value in word_to_id.items()}

    train_data = [[id_to_word[i] for i in sentence] for sentence in train_data]
    test_data = [[id_to_word[i] for i in sentence] for sentence in test_data]
    
    if mode == TRAIN:
        input_list = train_data
        target_list = train_labels
    else:
        input_list = test_data
        target_list = test_labels
    
    if mode == PREDICT:
        return input_list, target_list, label_encoder
        
    return create_single_problem_generator('imdb_cls', input_list, target_list, label_encoder, params, tokenizer, mode)

new_problem_process_fn_dict = {'imdb_cls': imdb_cls}

# %% [markdown]
# ## Train Model
#
# Please make sure you're using the correct checkpoint to initialize model.

# %%
params = DynamicBatchSizeParams()
params.init_checkpoint = 'models/cased_L-12_H-768_A-12'
tf.logging.set_verbosity(tf.logging.DEBUG)
train_bert_multitask(problem='imdb_cls', num_gpus=1, 
                     num_epochs=10, params=params, 
                     problem_type_dict=new_problem_type, processing_fn_dict=new_problem_process_fn_dict)
# Out:
# Adding new problem imdb_cls, problem type: cls
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:CPU:0
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_CPU:0
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_GPU:0
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_GPU:1
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_GPU:2
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_GPU:3
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:GPU:1
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:GPU:2
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:GPU:3
# INFO:tensorflow:Configured nccl all-reduce.
# INFO:tensorflow:Initializing RunConfig with distribution strategies.
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Using config: {'_model_dir': 'models/imdb_cls_ckpt', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': <tensorflow.contrib.distribute.python.mirrored_strategy.MirroredStrategy object at 0x7fcec8f2b0b8>, '_device_fn': None, '_protocol': None, '_eval_distribute': <tensorflow.contrib.distribute.python.mirrored_strategy.MirroredStrategy object at 0x7fcec8f2b0b8>, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcec8f2b7b8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_distribute_coordinator_mode': None}
# INFO:tensorflow:Create RestoreCheckpointHook.
# INFO:tensorflow:{'input_ids': tf.int32, 'input_mask': tf.int32, 'segment_ids': tf.int32, 'imdb_cls_loss_multiplier': tf.int32, 'imdb_cls_label_ids': tf.int32}
# INFO:tensorflow:{'input_ids': [None], 'input_mask': [None], 'segment_ids': [None], 'imdb_cls_loss_multiplier': [], 'imdb_cls_label_ids': []}
# WARNING:tensorflow:From /data3/yjp/anaconda3/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py:429: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#
# WARNING:tensorflow:From /data3/yjp/anaconda3/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py:1419: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /data3/yjp/bert-multitask-learning/bert_multitask_learning/bert/modeling.py:359: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /data3/yjp/bert-multitask-learning/bert_multitask_learning/bert/modeling.py:673: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# DEBUG:tensorflow:Converted call: <function stop_grad at 0x7fcec8ec9e18>; owner: None
# DEBUG:tensorflow:Converting <function stop_grad at 0x7fcec8ec9e18>
# DEBUG:tensorflow:Compiled output of <function stop_grad at 0x7fcec8ec9e18>:
#
# def stop_grad(global_step, tensor, freeze_step):
#   try:
#     with ag__.function_scope('stop_grad'):
#       cond_1 = ag__.gt(freeze_step, 0)
#
#       def if_true_1():
#         with ag__.function_scope('if_true_1'):
#           tensor_2, = tensor,
#           cond = ag__.lt_e(global_step, freeze_step)
#
#           def if_true():
#             with ag__.function_scope('if_true'):
#               tensor_1, = tensor_2,
#               tensor_1 = tf.stop_gradient(tensor_1)
#               return tensor_1
#
#           def if_false():
#             with ag__.function_scope('if_false'):
#               return tensor_2
#           tensor_2 = ag__.if_stmt(cond, if_true, if_false)
#           return tensor_2
#
#       def if_false_1():
#         with ag__.function_scope('if_false_1'):
#           return tensor
#       tensor = ag__.if_stmt(cond_1, if_true_1, if_false_1)
#       return tensor
#   except:
#     ag__.rewrite_graph_construction_error(ag_source_map__)
#
#
#
# stop_grad.autograph_info__ = {}
#
#
# WARNING:tensorflow:From /data3/yjp/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/losses/losses_impl.py:209: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# DEBUG:tensorflow:Converted call: <function filter_loss at 0x7fcec8ed4158>; owner: None
# DEBUG:tensorflow:Converting <function filter_loss at 0x7fcec8ed4158>
# DEBUG:tensorflow:Compiled output of <function filter_loss at 0x7fcec8ed4158>:
#
# def filter_loss(loss, features, problem):
#   try:
#     with ag__.function_scope('filter_loss'):
#       cond = ag__.eq(tf.reduce_mean(ag__.get_item(features, '%s_loss_multiplier' % problem, opts=ag__.GetItemOpts(element_dtype=None))), 0)
#
#       def if_true():
#         with ag__.function_scope('if_true'):
#           return_loss = 0.0
#           return return_loss
#
#       def if_false():
#         with ag__.function_scope('if_false'):
#           return_loss = loss
#           return return_loss
#       return_loss = ag__.if_stmt(cond, if_true, if_false)
#       return return_loss
#   except:
#     ag__.rewrite_graph_construction_error(ag_source_map__)
#
#
#
# filter_loss.autograph_info__ = {}
#
#
# WARNING:tensorflow:From /data3/yjp/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/learning_rate_decay_v2.py:321: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /data3/yjp/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /data3/yjp/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:tensorflow:batch_all_reduce invoked for batches size = 201 with algorithm = nccl, num_packs = 1, agg_small_grads_max_bytes = 0 and agg_small_grads_max_group = 10
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# DEBUG:tensorflow:Initialize variable bert/embeddings/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/embeddings/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/embeddings/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/embeddings/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/embeddings/position_embeddings:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/embeddings/position_embeddings
# DEBUG:tensorflow:Initialize variable bert/embeddings/token_type_embeddings:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/embeddings/token_type_embeddings
# DEBUG:tensorflow:Initialize variable bert/embeddings/word_embeddings:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/embeddings/word_embeddings
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/attention/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/attention/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/attention/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/attention/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/attention/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/attention/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/attention/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/attention/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/attention/self/key/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/attention/self/key/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/attention/self/key/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/attention/self/key/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/attention/self/query/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/attention/self/query/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/attention/self/query/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/attention/self/query/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/attention/self/value/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/attention/self/value/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/attention/self/value/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/attention/self/value/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/intermediate/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/intermediate/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/intermediate/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/intermediate/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_0/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_0/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/attention/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/attention/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/attention/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/attention/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/attention/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/attention/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/attention/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/attention/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/attention/self/key/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/attention/self/key/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/attention/self/key/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/attention/self/key/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/attention/self/query/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/attention/self/query/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/attention/self/query/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/attention/self/query/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/attention/self/value/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/attention/self/value/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/attention/self/value/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/attention/self/value/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/intermediate/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/intermediate/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/intermediate/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/intermediate/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_1/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_1/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/attention/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/attention/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/attention/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/attention/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/attention/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/attention/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/attention/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/attention/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/attention/self/key/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/attention/self/key/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/attention/self/key/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/attention/self/key/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/attention/self/query/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/attention/self/query/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/attention/self/query/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/attention/self/query/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/attention/self/value/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/attention/self/value/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/attention/self/value/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/attention/self/value/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/intermediate/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/intermediate/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/intermediate/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/intermediate/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_10/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_10/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/attention/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/attention/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/attention/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/attention/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/attention/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/attention/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/attention/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/attention/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/attention/self/key/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/attention/self/key/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/attention/self/key/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/attention/self/key/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/attention/self/query/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/attention/self/query/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/attention/self/query/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/attention/self/query/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/attention/self/value/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/attention/self/value/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/attention/self/value/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/attention/self/value/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/intermediate/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/intermediate/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/intermediate/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/intermediate/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_11/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_11/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/attention/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/attention/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/attention/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/attention/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/attention/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/attention/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/attention/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/attention/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/attention/self/key/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/attention/self/key/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/attention/self/key/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/attention/self/key/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/attention/self/query/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/attention/self/query/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/attention/self/query/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/attention/self/query/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/attention/self/value/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/attention/self/value/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/attention/self/value/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/attention/self/value/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/intermediate/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/intermediate/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/intermediate/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/intermediate/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_2/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_2/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/attention/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/attention/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/attention/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/attention/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/attention/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/attention/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/attention/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/attention/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/attention/self/key/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/attention/self/key/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/attention/self/key/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/attention/self/key/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/attention/self/query/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/attention/self/query/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/attention/self/query/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/attention/self/query/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/attention/self/value/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/attention/self/value/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/attention/self/value/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/attention/self/value/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/intermediate/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/intermediate/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/intermediate/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/intermediate/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_3/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_3/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/attention/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/attention/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/attention/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/attention/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/attention/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/attention/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/attention/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/attention/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/attention/self/key/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/attention/self/key/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/attention/self/key/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/attention/self/key/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/attention/self/query/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/attention/self/query/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/attention/self/query/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/attention/self/query/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/attention/self/value/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/attention/self/value/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/attention/self/value/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/attention/self/value/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/intermediate/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/intermediate/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/intermediate/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/intermediate/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_4/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_4/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/attention/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/attention/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/attention/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/attention/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/attention/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/attention/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/attention/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/attention/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/attention/self/key/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/attention/self/key/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/attention/self/key/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/attention/self/key/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/attention/self/query/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/attention/self/query/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/attention/self/query/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/attention/self/query/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/attention/self/value/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/attention/self/value/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/attention/self/value/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/attention/self/value/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/intermediate/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/intermediate/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/intermediate/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/intermediate/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_5/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_5/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/attention/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/attention/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/attention/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/attention/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/attention/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/attention/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/attention/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/attention/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/attention/self/key/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/attention/self/key/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/attention/self/key/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/attention/self/key/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/attention/self/query/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/attention/self/query/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/attention/self/query/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/attention/self/query/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/attention/self/value/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/attention/self/value/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/attention/self/value/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/attention/self/value/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/intermediate/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/intermediate/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/intermediate/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/intermediate/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_6/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_6/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/attention/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/attention/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/attention/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/attention/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/attention/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/attention/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/attention/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/attention/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/attention/self/key/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/attention/self/key/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/attention/self/key/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/attention/self/key/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/attention/self/query/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/attention/self/query/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/attention/self/query/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/attention/self/query/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/attention/self/value/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/attention/self/value/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/attention/self/value/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/attention/self/value/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/intermediate/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/intermediate/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/intermediate/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/intermediate/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_7/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_7/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/attention/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/attention/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/attention/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/attention/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/attention/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/attention/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/attention/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/attention/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/attention/self/key/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/attention/self/key/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/attention/self/key/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/attention/self/key/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/attention/self/query/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/attention/self/query/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/attention/self/query/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/attention/self/query/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/attention/self/value/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/attention/self/value/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/attention/self/value/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/attention/self/value/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/intermediate/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/intermediate/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/intermediate/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/intermediate/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_8/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_8/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/attention/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/attention/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/attention/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/attention/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/attention/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/attention/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/attention/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/attention/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/attention/self/key/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/attention/self/key/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/attention/self/key/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/attention/self/key/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/attention/self/query/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/attention/self/query/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/attention/self/query/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/attention/self/query/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/attention/self/value/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/attention/self/value/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/attention/self/value/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/attention/self/value/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/intermediate/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/intermediate/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/intermediate/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/intermediate/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/output/LayerNorm/beta:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/output/LayerNorm/beta
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/output/LayerNorm/gamma:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/output/LayerNorm/gamma
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/output/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/output/dense/bias
# DEBUG:tensorflow:Initialize variable bert/encoder/layer_9/output/dense/kernel:0 from checkpoint models/cased_L-12_H-768_A-12 with bert/encoder/layer_9/output/dense/kernel
# DEBUG:tensorflow:Initialize variable bert/pooler/dense/bias:0 from checkpoint models/cased_L-12_H-768_A-12 with bert
model.ckpt.
# INFO:tensorflow:global_step/sec: 1.70519
# INFO:tensorflow:loss = 0.0010170118, step = 7400 (58.634 sec)
# INFO:tensorflow:imdb_cls_loss = 0.0010170118, learning_rate = 1.0547876e-06, total_training_steps = 7812 (58.627 sec)
# INFO:tensorflow:global_step/sec: 1.81221
# INFO:tensorflow:loss = 0.00094073743, step = 7500 (55.190 sec)
# INFO:tensorflow:imdb_cls_loss = 0.00094073743, learning_rate = 7.9877134e-07, total_training_steps = 7812 (55.197 sec)
# INFO:tensorflow:global_step/sec: 1.80095
# INFO:tensorflow:loss = 0.00096715847, step = 7800 (55.514 sec)
# INFO:tensorflow:imdb_cls_loss = 0.00096715847, learning_rate = 3.0721424e-08, total_training_steps = 7812 (55.511 sec)
# INFO:tensorflow:Saving checkpoints for 7812 into models/imdb_cls_ckpt/model.ckpt.
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Loss for final step: 0.00074782525.

# %% [markdown]
# ## Evaluate Model

# %%
print(eval_bert_multitask(problem='imdb_cls', num_gpus=1, 
                     params=params, eval_scheme='acc',
                     problem_type_dict=new_problem_type, processing_fn_dict=new_problem_process_fn_dict))
# Out:
# Params problem assigned. Problem list: ['imdb_cls']
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:CPU:0
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_CPU:0
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_GPU:0
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_GPU:1
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_GPU:2
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_GPU:3
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:GPU:1
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:GPU:2
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:GPU:3
# INFO:tensorflow:Configured nccl all-reduce.
# INFO:tensorflow:Initializing RunConfig with distribution strategies.
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Using config: {'_model_dir': 'models/imdb_cls_ckpt', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': <tensorflow.contrib.distribute.python.mirrored_strategy.MirroredStrategy object at 0x7fcec8f2bdd8>, '_device_fn': None, '_protocol': None, '_eval_distribute': <tensorflow.contrib.distribute.python.mirrored_strategy.MirroredStrategy object at 0x7fcec8f2bdd8>, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcec8e30048>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_distribute_coordinator_mode': None}
# INFO:tensorflow:Calling model_fn.
# DEBUG:tensorflow:Converted call: <function stop_grad at 0x7fcec8ec9e18>; owner: None
# DEBUG:tensorflow:Converting <function stop_grad at 0x7fcec8ec9e18>
# DEBUG:tensorflow:Compiled output of <function stop_grad at 0x7fcec8ec9e18>:
#
# def stop_grad(global_step, tensor, freeze_step):
#   try:
#     with ag__.function_scope('stop_grad'):
#       cond_1 = ag__.gt(freeze_step, 0)
#
#       def if_true_1():
#         with ag__.function_scope('if_true_1'):
#           tensor_2, = tensor,
#           cond = ag__.lt_e(global_step, freeze_step)
#
#           def if_true():
#             with ag__.function_scope('if_true'):
#               tensor_1, = tensor_2,
#               tensor_1 = tf.stop_gradient(tensor_1)
#               return tensor_1
#
#           def if_false():
#             with ag__.function_scope('if_false'):
#               return tensor_2
#           tensor_2 = ag__.if_stmt(cond, if_true, if_false)
#           return tensor_2
#
#       def if_false_1():
#         with ag__.function_scope('if_false_1'):
#           return tensor
#       tensor = ag__.if_stmt(cond_1, if_true_1, if_false_1)
#       return tensor
#   except:
#     ag__.rewrite_graph_construction_error(ag_source_map__)
#
#
#
# stop_grad.autograph_info__ = {}
#
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/imdb_cls_ckpt/model.ckpt-7812
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Processing Inputs: 100%|██████████| 25000/25000 [04:53<00:00, 85.21it/s]
# {'imdb_cls_Accuracy': 0.91272, 'imdb_cls_Accuracy Per Sequence': 0.91272}
